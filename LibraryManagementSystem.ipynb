# %%
class Book:
    def __init__(self, book_id, name, author):
        self.book_id = book_id
        self.name = name
        self.author = author

    def __str__(self):
        return f"ID: {self.book_id}, Name: {self.name}, Author: {self.author}"

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print("Book added successfully.")

    def remove_book(self, book_id):
        for book in self.books:
            if book.book_id == book_id:
                self.books.remove(book)
                print("Book removed successfully.")
                return
        print("Book not found.")

    def list_books(self):
        if not self.books:
            print("No books available.")
            return
        print("Listing all books:")
        for book in self.books:
            print(book)

def library_management_system():
    library = Library()

    while True:
        print("\nLibrary Management System")
        print("1. Add Book")
        print("2. Remove Book")
        print("3. List All Books")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            book_id = int(input("Enter Book ID: "))
            name = input("Enter Book Name: ")
            author = input("Enter Author Name: ")
            book = Book(book_id, name, author)
            library.add_book(book)

        elif choice == '2':
            book_id = int(input("Enter Book ID to remove: "))
            library.remove_book(book_id)

        elif choice == '3':
            library.list_books()

        elif choice == '4':
            print("Exiting...")
            break

        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    library_management_system()
# Out:
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 1
# Enter Book ID: 101
# Enter Book Name: Python Programming
# Enter Author Name: Gudio Van Rossum
# Book added successfully.
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 1
# Enter Book ID: 102
# Enter Book Name: Java Programming
# Enter Author Name: James Gosling
# Book added successfully.
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 1
# Enter Book ID: 103
# Enter Book Name: One Piece
# Enter Author Name: Eiichiro Oda
# Book added successfully.
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 1
# Enter Book ID: 104
# Enter Book Name: Naruto
# Enter Author Name: Masashi Kishimoto
# Book added successfully.
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 3
# Listing all books:
# ID: 101, Name: Python Programming, Author: Gudio Van Rossum
# ID: 102, Name: Java Programming, Author: James Gosling
# ID: 103, Name: One Piece, Author: Eiichiro Oda
# ID: 104, Name: Naruto, Author: Masashi Kishimoto
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 2
# Enter Book ID to remove: 104
# Book removed successfully.
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 3
# Listing all books:
# ID: 101, Name: Python Programming, Author: Gudio Van Rossum
# ID: 102, Name: Java Programming, Author: James Gosling
# ID: 103, Name: One Piece, Author: Eiichiro Oda
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 2
# Enter Book ID to remove: 104
# Book not found.
#
# Library Management System
# 1. Add Book
# 2. Remove Book
# 3. List All Books
# 4. Exit
# Enter your choice: 4
# Exiting...
